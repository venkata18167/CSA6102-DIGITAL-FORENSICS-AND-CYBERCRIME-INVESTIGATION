# %% [markdown]
# <a href="https://colab.research.google.com/github/venkata18167/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/5.exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
case_name = input("Enter Case Name: ")
investigator = input("Enter Investigator Name: ")

print("\n========== DIGITAL FORENSIC REPORT ==========")
print("Case Name      :", case_name)
print("Investigator   :", investigator)

print("\n1. Identification")
print("Evidence identified and secured.")

print("\n2. Preservation")
print("Evidence preserved without modification.")

print("\n3. Collection")
print("Digital evidence collected from the system.")

print("\n4. Examination & Analysis")
print("Evidence examined and analyzed for findings.")

print("\n5. Reporting")
print("Investigation report prepared and submitted.")

print("\n========== END OF REPORT ==========")
# Out:
# Enter Case Name: Phishing Attack Investigation
# Enter Investigator Name:  T Venkat Reddy
#
# ========== DIGITAL FORENSIC REPORT ==========
# Case Name      : Phishing Attack Investigation
# Investigator   :  T Venkat Reddy
#
# 1. Identification
# Evidence identified and secured.
#
# 2. Preservation
# Evidence preserved without modification.
#
# 3. Collection
# Digital evidence collected from the system.
#
# 4. Examination & Analysis
# Evidence examined and analyzed for findings.
#
# 5. Reporting
# Investigation report prepared and submitted.
#
# ========== END OF REPORT ==========
