# %% [markdown]
# <a href="https://colab.research.google.com/github/venkata18167/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/13_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
case_name = "Phishing Investigation"
investigator = "T Venkat Reddy"
date = "21-07-2026"

findings = [
    "Suspicious login attempts detected from IP 192.168.1.10.",
    "SHA-256 hash verified successfully.",
    "Spoofed email header identified.",
    "Port scanning activity detected.",
    "Recovered deleted PDF file from storage image."
]
report = f"""
=========================================
        DIGITAL FORENSIC REPORT
=========================================

Case Name      : {case_name}
Investigator   : {investigator}
Date           : {date}

Investigation Findings:
"""

for i, item in enumerate(findings, start=1):
    report += f"{i}. {item}\n"

report += """
Conclusion:
The digital evidence was successfully analyzed.
The identified security incidents have been documented.

Status: Investigation Completed
=========================================
"""
with open("Digital_Forensic_Report.txt", "w") as file:
    file.write(report)
print(report)

print("Report saved as 'Digital_Forensic_Report.txt'")
# Out:
# ...
#         DIGITAL FORENSIC REPORT
# ...
#
# Case Name      : Phishing Investigation
# Investigator   : T Venkat Reddy
# Date           : 21-07-2026
#
# Investigation Findings:
# 1. Suspicious login attempts detected from IP 192.168.1.10.
# 2. SHA-256 hash verified successfully.
# 3. Spoofed email header identified.
# 4. Port scanning activity detected.
# 5. Recovered deleted PDF file from storage image.
#
# Conclusion:
# The digital evidence was successfully analyzed.
# The identified security incidents have been documented.
#
# Status: Investigation Completed
# ...
#
# Report saved as 'Digital_Forensic_Report.txt'
